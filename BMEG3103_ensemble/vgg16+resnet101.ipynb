# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

train_dir = 'BMEG3103_project/project1_dataset/train'
val_dir = 'BMEG3103_project/project1_dataset/val'
test_dir = 'BMEG3103_project/project1_dataset/test'
# Out:
# 2024-11-25 03:17:10.878332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732475830.887106   42376 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732475830.889731   42376 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 03:17:10.898826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.4, 1.6],
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 4192 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.
# Found 698 images belonging to 2 classes.

# %%
vgg16_base = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

resnet101_base = tf.keras.applications.ResNet101(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

vgg16_base.trainable = True
resnet101_base.trainable = True
# Out:
# I0000 00:00:1732475833.792681   42376 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13553 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for layer in vgg16_base.layers[:15]:
    layer.trainable = False
for layer in resnet101_base.layers[:15]:
    layer.trainable = False

input_layer = tf.keras.Input(shape=(224, 224, 3))

vgg16_output = vgg16_base(input_layer)
resnet101_output = resnet101_base(input_layer)

vgg16_output = tf.keras.layers.GlobalAveragePooling2D()(vgg16_output)
resnet101_output = tf.keras.layers.GlobalAveragePooling2D()(resnet101_output)

# %%
from tensorflow.keras.layers import BatchNormalization, Dense
from tensorflow.keras.regularizers import l1, l2, l1_l2

combined = tf.keras.layers.concatenate([vgg16_output, resnet101_output])

x = tf.keras.layers.BatchNormalization()(combined)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=0.1))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(2, activation='softmax')(x)
                                                       
model = tf.keras.Model(inputs=input_layer, outputs=output)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

def cosine_annealing(epoch, lr, total_epochs):
    return 0.5 * lr * (1 + np.cos(np.pi * epoch / total_epochs))

total_epochs = 200

lr_scheduler = LearningRateScheduler(lambda epoch, lr: cosine_annealing(epoch, lr, total_epochs))

# %%
history = model.fit(
    train_generator,
    epochs=total_epochs,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /home/user/miniconda3/envs/tensorflow/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732475863.520122   42617 service.cc:148] XLA service 0x7f26a80029c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732475863.520149   42617 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2024-11-25 03:17:44.283438: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732475867.256804   42617 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1732475888.858874   42617 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.6833 - loss: 1407.8143 - val_accuracy: 0.5240 - val_loss: 1112.0255 - learning_rate: 1.0000e-04
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.8243 - loss: 1023.4144 - val_accuracy: 0.9067 - val_loss: 773.2853 - learning_rate: 9.9994e-05
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.8685 - loss: 700.1537 - val_accuracy: 0.7933 - val_loss: 496.5491 - learning_rate: 9.9969e-05
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.8930 - loss: 438.1693 - val_accuracy: 0.5885 - val_loss: 281.4312 - learning_rate: 9.9914e-05
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 679ms/step - accuracy: 0.9031 - loss: 238.5464 - val_accuracy: 0.8298 - val_loss: 127.6371 - learning_rate: 9.9815e-05
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 676ms/step - accuracy: 0.9179 - loss: 100.1741 - val_accuracy: 0.7433 - val_loss: 35.1341 - learning_rate: 9.9661e-05
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9132 - loss: 23.0781 - val_accuracy: 0.8663 - val_loss: 4.7163 - learning_rate: 9.9440e-05
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 698ms/step - accuracy: 0.9083 - loss: 4.0289 - val_accuracy: 0.7913 - val_loss: 2.8479 - learning_rate: 9.9140e-05
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 696ms/step - accuracy: 0.9208 - loss: 2.5933 - val_accuracy: 0.9413 - val_loss: 2.2067 - learning_rate: 9.8749e-05
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9341 - loss: 2.0442 - val_accuracy: 0.9471 - val_loss: 2.4362 - learning_rate: 9.8256e-05
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 692ms/step - accuracy: 0.9339 - loss: 2.0862 - val_accuracy: 0.8692 - val_loss: 2.1987 - learning_rate: 9.7652e-05
# Epoch 12/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 692ms/step - accuracy: 0.9519 - loss: 1.9647 - val_accuracy: 0.8433 - val_loss: 2.0399 - learning_rate: 9.6924e-05
# Epoch 13/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.
# Epoch 42/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 691ms/step - accuracy: 0.9741 - loss: 0.4904 - val_accuracy: 0.9365 - val_loss: 0.6293 - learning_rate: 2.2643e-05
# Epoch 43/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 692ms/step - accuracy: 0.9794 - loss: 0.4203 - val_accuracy: 0.9490 - val_loss: 0.4942 - learning_rate: 2.0267e-05
# Epoch 44/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 688ms/step - accuracy: 0.9800 - loss: 0.3878 - val_accuracy: 0.9087 - val_loss: 0.7151 - learning_rate: 1.8042e-05
# Epoch 45/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 679ms/step - accuracy: 0.9829 - loss: 0.3523 - val_accuracy: 0.9587 - val_loss: 0.3714 - learning_rate: 1.5972e-05
# Epoch 46/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 688ms/step - accuracy: 0.9820 - loss: 0.3102 - val_accuracy: 0.9683 - val_loss: 0.3550 - learning_rate: 1.4058e-05
# Epoch 47/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 695ms/step - accuracy: 0.9840 - loss: 0.3047 - val_accuracy: 0.9567 - val_loss: 0.3360 - learning_rate: 1.2302e-05
# Epoch 48/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9849 - loss: 0.2648 - val_accuracy: 0.9500 - val_loss: 0.3471 - learning_rate: 1.0700e-05
# Epoch 49/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9876 - loss: 0.2292 - val_accuracy: 0.9433 - val_loss: 0.3045 - learning_rate: 9.2503e-06
# Epoch 50/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9851 - loss: 0.2133 - val_accuracy: 0.9519 - val_loss: 0.2935 - learning_rate: 7.9466e-06
# Epoch 51/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9856 - loss: 0.1892 - val_accuracy: 0.9433 - val_loss: 0.3051 - learning_rate: 6.7829e-06
# Epoch 52/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 681ms/step - accuracy: 0.9825 - loss: 0.1864 - val_accuracy: 0.9558 - val_loss: 0.2684 - learning_rate: 5.7516e-06
# Epoch 53/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.9875 - loss: 0.1809 - val_accuracy: 0.9519 - val_loss: 0.2502 - learning_rate: 4.8444e-06
# Epoch 54/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9847 - loss: 0.1605 - val_accuracy: 0.9567 - val_loss: 0.2323 - learning_rate: 4.0524e-06
# Epoch 55/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9862 - loss: 0.1694 - val_accuracy: 0.9644 - val_loss: 0.2112 - learning_rate: 3.3661e-06
# Epoch 56/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 697ms/step - accuracy: 0.9827 - loss: 0.1579 - val_accuracy: 0.9596 - val_loss: 0.2230 - learning_rate: 2.7761e-06
# Epoch 57/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9864 - loss: 0.1492 - val_accuracy: 0.9644 - val_loss: 0.1912 - learning_rate: 2.2728e-06
# Epoch 58/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9857 - loss: 0.1383 - val_accuracy: 0.9654 - val_loss: 0.1935 - learning_rate: 1.8470e-06
# Epoch 59/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9758 - loss: 0.1497 - val_accuracy: 0.9538 - val_loss: 0.2117 - learning_rate: 1.4895e-06
# Epoch 60/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 680ms/step - accuracy: 0.9848 - loss: 0.1352 - val_accuracy: 0.9644 - val_loss: 0.1870 - learning_rate: 1.1919e-06
# Epoch 61/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9802 - loss: 0.1330 - val_accuracy: 0.9663 - val_loss: 0.1715 - learning_rate: 9.4625e-07
# Epoch 62/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9890 - loss: 0.1229 - val_accuracy: 0.9596 - val_loss: 0.1908 - learning_rate: 7.4517e-07
# Epoch 63/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 700ms/step - accuracy: 0.9878 - loss: 0.1249 - val_accuracy: 0.9663 - val_loss: 0.1803 - learning_rate: 5.8201e-07
# Epoch 64/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 696ms/step - accuracy: 0.9882 - loss: 0.1151 - val_accuracy: 0.9663 - val_loss: 0.1720 - learning_rate: 4.5077e-07
# Epoch 65/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9893 - loss: 0.1102 - val_accuracy: 0.9654 - val_loss: 0.1723 - learning_rate: 3.4615e-07
# Epoch 66/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9845 - loss: 0.1199 - val_accuracy: 0.9654 - val_loss: 0.1686 - learning_rate: 2.6351e-07
# Epoch 67/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9867 - loss: 0.1200 - val_accuracy: 0.9654 - val_loss: 0.1751 - learning_rate: 1.9882e-07
# Epoch 68/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9868 - loss: 0.1165 - val_accuracy: 0.9673 - val_loss: 0.1617 - learning_rate: 1.4867e-07
# Epoch 69/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 82s 683ms/step - accuracy: 0.9877 - loss: 0.1133 - val_accuracy: 0.9654 - val_loss: 0.1673 - learning_rate: 1.1014e-07
# Epoch 70/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9877 - loss: 0.1130 - val_accuracy: 0.9663 - val_loss: 0.1649 - learning_rate: 8.0841e-08
# Epoch 71/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9871 - loss: 0.1140 - val_accuracy: 0.9663 - val_loss: 0.1653 - learning_rate: 5.8771e-08
# Epoch 72/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9855 - loss: 0.1180 - val_accuracy: 0.9663 - val_loss: 0.1663 - learning_rate: 4.2314e-08
# Epoch 73/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9871 - loss: 0.1153 - val_accuracy: 0.9654 - val_loss: 0.1675 - learning_rate: 3.0165e-08
# Epoch 74/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 82s 680ms/step - accuracy: 0.9845 - loss: 0.1148 - val_accuracy: 0.9663 - val_loss: 0.1664 - learning_rate: 2.1289e-08
# Epoch 75/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 677ms/step - accuracy: 0.9850 - loss: 0.1155 - val_accuracy: 0.9663 - val_loss: 0.1653 - learning_rate: 1.4872e-08
# Epoch 76/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9787 - loss: 0.1330 - val_accuracy: 0.9654 - val_loss: 0.1658 - learning_rate: 1.0282e-08
# Epoch 77/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9832 - loss: 0.1188 - val_accuracy: 0.9663 - val_loss: 0.1658 - learning_rate: 7.0333e-09
# Epoch 78/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 697ms/step - accuracy: 0.9854 - loss: 0.1176 - val_accuracy: 0.9654 - val_loss: 0.1656 - learning_rate: 4.7597e-09
# Epoch 79/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9858 - loss: 0.1153 - val_accuracy: 0.9663 - val_loss: 0.1654 - learning_rate: 3.1860e-09
# Epoch 80/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 691ms/step - accuracy: 0.9880 - loss: 0.1118 - val_accuracy: 0.9663 - val_loss: 0.1645 - learning_rate: 2.1090e-09
# Epoch 81/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9887 - loss: 0.1124 - val_accuracy: 0.9654 - val_loss: 0.1652 - learning_rate: 1.3804e-09
# Epoch 82/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9882 - loss: 0.1089 - val_accuracy: 0.9654 - val_loss: 0.1652 - learning_rate: 8.9312e-10
# Epoch 83/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9845 - loss: 0.1144 - val_accuracy: 0.9663 - val_loss: 0.1635 - learning_rate: 5.7114e-10
# Epoch 84/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9916 - loss: 0.1075 - val_accuracy: 0.9663 - val_loss: 0.1631 - learning_rate: 3.6093e-10
# Epoch 85/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 695ms/step - accuracy: 0.9853 - loss: 0.1142 - val_accuracy: 0.9663 - val_loss: 0.1653 - learning_rate: 2.2534e-10
# Epoch 86/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9853 - loss: 0.1178 - val_accuracy: 0.9663 - val_loss: 0.1652 - learning_rate: 1.3897e-10
# Epoch 87/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9864 - loss: 0.1184 - val_accuracy: 0.9663 - val_loss: 0.1650 - learning_rate: 8.4645e-11
# Epoch 88/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9876 - loss: 0.1091 - val_accuracy: 0.9654 - val_loss: 0.1657 - learning_rate: 5.0905e-11

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

test_generator.reset()
preds = model.predict(test_generator)
preds = np.argmax(preds, axis=1)
true_labels = test_generator.classes
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9082 - loss: 0.2883
# Test Accuracy: 0.9355
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 494ms/step

# %%
threshold = 0.5 
preds = (model.predict(test_generator)[:, 1] > threshold).astype(int)

test_precision = precision_score(true_labels, preds)
test_recall = recall_score(true_labels, preds)
f1 = f1_score(true_labels, preds)
conf_matrix = confusion_matrix(true_labels, preds)

print(f'F1 Score: {f1:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step
# F1 Score: 0.9496
# Test Precision: 0.9197
# Test Recall: 0.9815
# Confusion Matrix:
# [[229  37]
#  [  8 424]]

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
