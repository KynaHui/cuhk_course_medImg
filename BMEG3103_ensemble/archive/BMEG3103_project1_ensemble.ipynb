# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

train_dir = 'BMEG3103_project/project1_dataset/train'
val_dir = 'BMEG3103_project/project1_dataset/val'
test_dir = 'BMEG3103_project/project1_dataset/test'
# Out:
# 2024-11-23 16:01:26.476354: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732348886.485242    9612 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732348886.487796    9612 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-23 16:01:26.496868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.4, 1.6],
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 4192 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.
# Found 698 images belonging to 2 classes.

# %%
vgg16_base = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

resnet101_base = tf.keras.applications.ResNet101(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

vgg16_base.trainable = True
resnet101_base.trainable = True
# Out:
# I0000 00:00:1732348889.464542    9612 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13553 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for layer in vgg16_base.layers[:15]:
    layer.trainable = False
for layer in resnet101_base.layers[:15]:
    layer.trainable = False

input_layer = tf.keras.Input(shape=(224, 224, 3))

vgg16_output = vgg16_base(input_layer)
resnet101_output = resnet101_base(input_layer)

vgg16_output = tf.keras.layers.GlobalAveragePooling2D()(vgg16_output)
resnet101_output = tf.keras.layers.GlobalAveragePooling2D()(resnet101_output)

# %%
combined = tf.keras.layers.concatenate([vgg16_output, resnet101_output])

x = tf.keras.layers.BatchNormalization()(combined)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=input_layer, outputs=output)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

def cosine_annealing(epoch, lr, total_epochs):
    return 0.5 * lr * (1 + np.cos(np.pi * epoch / total_epochs))

total_epochs = 200

lr_scheduler = LearningRateScheduler(lambda epoch, lr: cosine_annealing(epoch, lr, total_epochs))

# %%
history = model.fit(
    train_generator,
    epochs=total_epochs,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /home/user/miniconda3/envs/tensorflow/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732348918.232384    9837 service.cc:148] XLA service 0x7f0fe0004050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732348918.232411    9837 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2024-11-23 16:01:58.989232: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732348921.912686    9837 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1732348942.707157    9837 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.6494 - loss: 5.5327 - val_accuracy: 0.7923 - val_loss: 4.7866 - learning_rate: 1.0000e-04
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.8074 - loss: 4.7565 - val_accuracy: 0.9481 - val_loss: 4.3405 - learning_rate: 9.9994e-05
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 677ms/step - accuracy: 0.8718 - loss: 4.2453 - val_accuracy: 0.7923 - val_loss: 4.0885 - learning_rate: 9.9969e-05
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.8768 - loss: 3.9373 - val_accuracy: 0.7442 - val_loss: 3.9576 - learning_rate: 9.9914e-05
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.8890 - loss: 3.6464 - val_accuracy: 0.9202 - val_loss: 3.3544 - learning_rate: 9.9815e-05
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9028 - loss: 3.3766 - val_accuracy: 0.7433 - val_loss: 3.7747 - learning_rate: 9.9661e-05
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 691ms/step - accuracy: 0.9248 - loss: 3.0863 - val_accuracy: 0.9221 - val_loss: 2.8834 - learning_rate: 9.9440e-05
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9205 - loss: 2.9108 - val_accuracy: 0.9250 - val_loss: 2.7313 - learning_rate: 9.9140e-05
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9255 - loss: 2.7200 - val_accuracy: 0.9413 - val_loss: 2.5035 - learning_rate: 9.8749e-05
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s
# Epoch 33/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 676ms/step - accuracy: 0.9760 - loss: 0.5780 - val_accuracy: 0.8885 - val_loss: 0.8727 - learning_rate: 4.9148e-05
# Epoch 34/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9749 - loss: 0.5554 - val_accuracy: 0.8981 - val_loss: 0.7938 - learning_rate: 4.5920e-05
# Epoch 35/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9674 - loss: 0.5492 - val_accuracy: 0.9519 - val_loss: 0.6034 - learning_rate: 4.2723e-05
# Epoch 36/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9654 - loss: 0.5331 - val_accuracy: 0.9394 - val_loss: 0.6311 - learning_rate: 3.9575e-05
# Epoch 37/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 696ms/step - accuracy: 0.9757 - loss: 0.5029 - val_accuracy: 0.9500 - val_loss: 0.6113 - learning_rate: 3.6494e-05
# Epoch 38/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 692ms/step - accuracy: 0.9731 - loss: 0.4825 - val_accuracy: 0.9413 - val_loss: 0.6081 - learning_rate: 3.3498e-05
# Epoch 39/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 82s 686ms/step - accuracy: 0.9762 - loss: 0.4567 - val_accuracy: 0.9462 - val_loss: 0.5865 - learning_rate: 3.0602e-05
# Epoch 40/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.9779 - loss: 0.4477 - val_accuracy: 0.9356 - val_loss: 0.6325 - learning_rate: 2.7820e-05
# Epoch 41/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 680ms/step - accuracy: 0.9779 - loss: 0.4431 - val_accuracy: 0.9471 - val_loss: 0.5677 - learning_rate: 2.5163e-05
# Epoch 42/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9774 - loss: 0.4227 - val_accuracy: 0.9038 - val_loss: 0.6977 - learning_rate: 2.2643e-05
# Epoch 43/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9725 - loss: 0.4234 - val_accuracy: 0.8981 - val_loss: 0.7137 - learning_rate: 2.0267e-05
# Epoch 44/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9775 - loss: 0.4076 - val_accuracy: 0.9250 - val_loss: 0.6164 - learning_rate: 1.8042e-05
# Epoch 45/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9864 - loss: 0.3811 - val_accuracy: 0.9212 - val_loss: 0.6172 - learning_rate: 1.5972e-05
# Epoch 46/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 754ms/step - accuracy: 0.9803 - loss: 0.3835 - val_accuracy: 0.9385 - val_loss: 0.5357 - learning_rate: 1.4058e-05
# Epoch 47/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.9828 - loss: 0.3759 - val_accuracy: 0.9019 - val_loss: 0.6974 - learning_rate: 1.2302e-05
# Epoch 48/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 676ms/step - accuracy: 0.9799 - loss: 0.3907 - val_accuracy: 0.9183 - val_loss: 0.6078 - learning_rate: 1.0700e-05
# Epoch 49/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 678ms/step - accuracy: 0.9822 - loss: 0.3702 - val_accuracy: 0.9423 - val_loss: 0.5147 - learning_rate: 9.2503e-06
# Epoch 50/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9813 - loss: 0.3655 - val_accuracy: 0.9385 - val_loss: 0.5228 - learning_rate: 7.9466e-06
# Epoch 51/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9782 - loss: 0.3686 - val_accuracy: 0.9298 - val_loss: 0.5489 - learning_rate: 6.7829e-06
# Epoch 52/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 702ms/step - accuracy: 0.9814 - loss: 0.3590 - val_accuracy: 0.9337 - val_loss: 0.5245 - learning_rate: 5.7516e-06
# Epoch 53/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9840 - loss: 0.3519 - val_accuracy: 0.9346 - val_loss: 0.5225 - learning_rate: 4.8444e-06
# Epoch 54/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 692ms/step - accuracy: 0.9801 - loss: 0.3683 - val_accuracy: 0.9356 - val_loss: 0.5281 - learning_rate: 4.0524e-06
# Epoch 55/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9844 - loss: 0.3498 - val_accuracy: 0.9279 - val_loss: 0.5618 - learning_rate: 3.3661e-06
# Epoch 56/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.9783 - loss: 0.3592 - val_accuracy: 0.9327 - val_loss: 0.5187 - learning_rate: 2.7761e-06
# Epoch 57/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 680ms/step - accuracy: 0.9770 - loss: 0.3646 - val_accuracy: 0.9212 - val_loss: 0.5829 - learning_rate: 2.2728e-06
# Epoch 58/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9809 - loss: 0.3484 - val_accuracy: 0.9202 - val_loss: 0.5912 - learning_rate: 1.8470e-06
# Epoch 59/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 691ms/step - accuracy: 0.9824 - loss: 0.3456 - val_accuracy: 0.9212 - val_loss: 0.5908 - learning_rate: 1.4895e-06
# Epoch 60/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 696ms/step - accuracy: 0.9853 - loss: 0.3523 - val_accuracy: 0.9260 - val_loss: 0.5715 - learning_rate: 1.1919e-06
# Epoch 61/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9837 - loss: 0.3464 - val_accuracy: 0.9250 - val_loss: 0.5677 - learning_rate: 9.4625e-07
# Epoch 62/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9798 - loss: 0.3486 - val_accuracy: 0.9279 - val_loss: 0.5533 - learning_rate: 7.4517e-07
# Epoch 63/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9810 - loss: 0.3550 - val_accuracy: 0.9279 - val_loss: 0.5559 - learning_rate: 5.8201e-07
# Epoch 64/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 681ms/step - accuracy: 0.9828 - loss: 0.3438 - val_accuracy: 0.9288 - val_loss: 0.5508 - learning_rate: 4.5077e-07
# Epoch 65/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9855 - loss: 0.3380 - val_accuracy: 0.9269 - val_loss: 0.5571 - learning_rate: 3.4615e-07
# Epoch 66/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 698ms/step - accuracy: 0.9788 - loss: 0.3454 - val_accuracy: 0.9279 - val_loss: 0.5508 - learning_rate: 2.6351e-07
# Epoch 67/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.9800 - loss: 0.3522 - val_accuracy: 0.9298 - val_loss: 0.5507 - learning_rate: 1.9882e-07
# Epoch 68/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 47s 705ms/step - accuracy: 0.9790 - loss: 0.3522 - val_accuracy: 0.9269 - val_loss: 0.5561 - learning_rate: 1.4867e-07
# Epoch 69/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 81s 687ms/step - accuracy: 0.9790 - loss: 0.3552 - val_accuracy: 0.9288 - val_loss: 0.5512 - learning_rate: 1.1014e-07

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

test_generator.reset()
preds = model.predict(test_generator)
preds = np.argmax(preds, axis=1)
true_labels = test_generator.classes
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9082 - loss: 0.5990
# Test Accuracy: 0.9298
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 506ms/step

# %%
threshold = 0.5  
preds = (model.predict(test_generator)[:, 1] > threshold).astype(int)

test_precision = precision_score(true_labels, preds)
test_recall = recall_score(true_labels, preds)
f1 = f1_score(true_labels, preds)
conf_matrix = confusion_matrix(true_labels, preds)

print(f'F1 Score: {f1:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step
# F1 Score: 0.9446
# Test Precision: 0.9227
# Test Recall: 0.9676
# Confusion Matrix:
# [[231  35]
#  [ 14 418]]

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
