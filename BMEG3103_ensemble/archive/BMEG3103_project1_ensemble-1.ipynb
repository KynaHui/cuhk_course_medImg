# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

train_dir = 'BMEG3103_project/project1_dataset/train'
val_dir = 'BMEG3103_project/project1_dataset/val'
test_dir = 'BMEG3103_project/project1_dataset/test'
# Out:
# 2024-11-23 20:59:56.458247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732366796.466805   15551 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732366796.469307   15551 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-23 20:59:56.478437: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.4, 1.6],
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 4192 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.
# Found 698 images belonging to 2 classes.

# %%
vgg16_base = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

resnet101_base = tf.keras.applications.ResNet101(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

vgg16_base.trainable = True
resnet101_base.trainable = True
# Out:
# I0000 00:00:1732366798.133222   15551 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13553 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for layer in vgg16_base.layers[:15]:
    layer.trainable = False
for layer in resnet101_base.layers[:15]:
    layer.trainable = False

input_layer = tf.keras.Input(shape=(224, 224, 3))

vgg16_output = vgg16_base(input_layer)
resnet101_output = resnet101_base(input_layer)

vgg16_output = tf.keras.layers.GlobalAveragePooling2D()(vgg16_output)
resnet101_output = tf.keras.layers.GlobalAveragePooling2D()(resnet101_output)

# %%
from tensorflow.keras.layers import BatchNormalization, Dense
from tensorflow.keras.regularizers import l1, l2, l1_l2

combined = tf.keras.layers.concatenate([vgg16_output, resnet101_output])

x = tf.keras.layers.BatchNormalization()(combined)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=l1(0.01))(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(2, activation='softmax')(x)
                                                       
model = tf.keras.Model(inputs=input_layer, outputs=output)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

def cosine_annealing(epoch, lr, total_epochs):
    return 0.5 * lr * (1 + np.cos(np.pi * epoch / total_epochs))

total_epochs = 200

lr_scheduler = LearningRateScheduler(lambda epoch, lr: cosine_annealing(epoch, lr, total_epochs))

# %%
history = model.fit(
    train_generator,
    epochs=total_epochs,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /home/user/miniconda3/envs/tensorflow/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732366826.338485   15774 service.cc:148] XLA service 0x7f19d0001cf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732366826.338509   15774 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2024-11-23 21:00:27.084915: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732366830.055033   15774 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1732366851.292064   15774 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.6493 - loss: 143.8008 - val_accuracy: 0.9202 - val_loss: 119.4901 - learning_rate: 1.0000e-04
# Epoch 2/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.8034 - loss: 112.0825 - val_accuracy: 0.9260 - val_loss: 90.7160 - learning_rate: 9.9994e-05
# Epoch 3/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 689ms/step - accuracy: 0.8545 - loss: 84.1898 - val_accuracy: 0.8240 - val_loss: 65.8186 - learning_rate: 9.9969e-05
# Epoch 4/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 679ms/step - accuracy: 0.8817 - loss: 60.4330 - val_accuracy: 0.9327 - val_loss: 45.1246 - learning_rate: 9.9914e-05
# Epoch 5/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 673ms/step - accuracy: 0.8867 - loss: 40.8520 - val_accuracy: 0.8885 - val_loss: 29.0469 - learning_rate: 9.9815e-05
# Epoch 6/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9060 - loss: 25.7093 - val_accuracy: 0.8740 - val_loss: 17.1992 - learning_rate: 9.9661e-05
# Epoch 7/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9156 - loss: 14.8851 - val_accuracy: 0.4846 - val_loss: 10.0146 - learning_rate: 9.9440e-05
# Epoch 8/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9294 - loss: 8.3683 - val_accuracy: 0.8221 - val_loss: 5.8214 - learning_rate: 9.9140e-05
# Epoch 9/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9277 - loss: 4.8851 - val_accuracy: 0.9385 - val_loss: 3.5411 - learning_rate: 9.8749e-05
# Epoch 10/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9186 - loss: 3.0337 - val_accuracy: 0.8952 - val_loss: 2.1627 - learning_rate: 9.8256e-05
# Epoch 11/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.
# Epoch 38/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 699ms/step - accuracy: 0.9683 - loss: 0.3592 - val_accuracy: 0.9558 - val_loss: 0.3130 - learning_rate: 3.3498e-05
# Epoch 39/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 682ms/step - accuracy: 0.9651 - loss: 0.2741 - val_accuracy: 0.8942 - val_loss: 0.5248 - learning_rate: 3.0602e-05
# Epoch 40/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9787 - loss: 0.2424 - val_accuracy: 0.9077 - val_loss: 0.4868 - learning_rate: 2.7820e-05
# Epoch 41/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9702 - loss: 0.2852 - val_accuracy: 0.9048 - val_loss: 0.4600 - learning_rate: 2.5163e-05
# Epoch 42/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 674ms/step - accuracy: 0.9745 - loss: 0.2268 - val_accuracy: 0.9423 - val_loss: 0.3243 - learning_rate: 2.2643e-05
# Epoch 43/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9789 - loss: 0.2133 - val_accuracy: 0.9202 - val_loss: 0.3600 - learning_rate: 2.0267e-05
# Epoch 44/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9787 - loss: 0.1633 - val_accuracy: 0.9356 - val_loss: 0.3121 - learning_rate: 1.8042e-05
# Epoch 45/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 697ms/step - accuracy: 0.9702 - loss: 0.1979 - val_accuracy: 0.9519 - val_loss: 0.2537 - learning_rate: 1.5972e-05
# Epoch 46/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 695ms/step - accuracy: 0.9811 - loss: 0.1515 - val_accuracy: 0.9433 - val_loss: 0.2588 - learning_rate: 1.4058e-05
# Epoch 47/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9803 - loss: 0.1390 - val_accuracy: 0.9346 - val_loss: 0.3061 - learning_rate: 1.2302e-05
# Epoch 48/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9720 - loss: 0.1498 - val_accuracy: 0.9279 - val_loss: 0.3325 - learning_rate: 1.0700e-05
# Epoch 49/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9761 - loss: 0.1503 - val_accuracy: 0.9404 - val_loss: 0.2656 - learning_rate: 9.2503e-06
# Epoch 50/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 673ms/step - accuracy: 0.9731 - loss: 0.1477 - val_accuracy: 0.9298 - val_loss: 0.2780 - learning_rate: 7.9466e-06
# Epoch 51/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 688ms/step - accuracy: 0.9795 - loss: 0.1377 - val_accuracy: 0.9337 - val_loss: 0.2694 - learning_rate: 6.7829e-06
# Epoch 52/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 693ms/step - accuracy: 0.9822 - loss: 0.1088 - val_accuracy: 0.9385 - val_loss: 0.2621 - learning_rate: 5.7516e-06
# Epoch 53/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 697ms/step - accuracy: 0.9741 - loss: 0.1394 - val_accuracy: 0.9500 - val_loss: 0.2242 - learning_rate: 4.8444e-06
# Epoch 54/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9813 - loss: 0.1147 - val_accuracy: 0.9423 - val_loss: 0.2401 - learning_rate: 4.0524e-06
# Epoch 55/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9824 - loss: 0.0989 - val_accuracy: 0.9529 - val_loss: 0.2097 - learning_rate: 3.3661e-06
# Epoch 56/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 691ms/step - accuracy: 0.9813 - loss: 0.1007 - val_accuracy: 0.9442 - val_loss: 0.2152 - learning_rate: 2.7761e-06
# Epoch 57/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9794 - loss: 0.1051 - val_accuracy: 0.9327 - val_loss: 0.2584 - learning_rate: 2.2728e-06
# Epoch 58/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 677ms/step - accuracy: 0.9821 - loss: 0.0930 - val_accuracy: 0.9433 - val_loss: 0.2352 - learning_rate: 1.8470e-06
# Epoch 59/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9843 - loss: 0.0909 - val_accuracy: 0.9442 - val_loss: 0.2216 - learning_rate: 1.4895e-06
# Epoch 60/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9854 - loss: 0.0887 - val_accuracy: 0.9462 - val_loss: 0.2053 - learning_rate: 1.1919e-06
# Epoch 61/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9862 - loss: 0.0830 - val_accuracy: 0.9452 - val_loss: 0.2191 - learning_rate: 9.4625e-07
# Epoch 62/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 694ms/step - accuracy: 0.9782 - loss: 0.0953 - val_accuracy: 0.9442 - val_loss: 0.2079 - learning_rate: 7.4517e-07
# Epoch 63/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 684ms/step - accuracy: 0.9823 - loss: 0.0917 - val_accuracy: 0.9433 - val_loss: 0.2217 - learning_rate: 5.8201e-07
# Epoch 64/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9816 - loss: 0.0830 - val_accuracy: 0.9433 - val_loss: 0.2223 - learning_rate: 4.5077e-07
# Epoch 65/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 681ms/step - accuracy: 0.9758 - loss: 0.1030 - val_accuracy: 0.9423 - val_loss: 0.2264 - learning_rate: 3.4615e-07
# Epoch 66/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 676ms/step - accuracy: 0.9811 - loss: 0.0897 - val_accuracy: 0.9404 - val_loss: 0.2313 - learning_rate: 2.6351e-07
# Epoch 67/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9788 - loss: 0.0955 - val_accuracy: 0.9404 - val_loss: 0.2297 - learning_rate: 1.9882e-07
# Epoch 68/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9857 - loss: 0.0754 - val_accuracy: 0.9413 - val_loss: 0.2249 - learning_rate: 1.4867e-07
# Epoch 69/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 698ms/step - accuracy: 0.9826 - loss: 0.0896 - val_accuracy: 0.9433 - val_loss: 0.2191 - learning_rate: 1.1014e-07
# Epoch 70/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 690ms/step - accuracy: 0.9778 - loss: 0.0880 - val_accuracy: 0.9423 - val_loss: 0.2255 - learning_rate: 8.0841e-08
# Epoch 71/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 683ms/step - accuracy: 0.9787 - loss: 0.0911 - val_accuracy: 0.9442 - val_loss: 0.2235 - learning_rate: 5.8771e-08
# Epoch 72/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 681ms/step - accuracy: 0.9794 - loss: 0.0826 - val_accuracy: 0.9442 - val_loss: 0.2250 - learning_rate: 4.2314e-08
# Epoch 73/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 679ms/step - accuracy: 0.9794 - loss: 0.0934 - val_accuracy: 0.9433 - val_loss: 0.2237 - learning_rate: 3.0165e-08
# Epoch 74/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 681ms/step - accuracy: 0.9821 - loss: 0.0876 - val_accuracy: 0.9442 - val_loss: 0.2237 - learning_rate: 2.1289e-08
# Epoch 75/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9798 - loss: 0.0871 - val_accuracy: 0.9413 - val_loss: 0.2264 - learning_rate: 1.4872e-08
# Epoch 76/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 687ms/step - accuracy: 0.9835 - loss: 0.0808 - val_accuracy: 0.9442 - val_loss: 0.2239 - learning_rate: 1.0282e-08
# Epoch 77/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 701ms/step - accuracy: 0.9840 - loss: 0.0782 - val_accuracy: 0.9442 - val_loss: 0.2235 - learning_rate: 7.0333e-09
# Epoch 78/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 686ms/step - accuracy: 0.9832 - loss: 0.0902 - val_accuracy: 0.9442 - val_loss: 0.2231 - learning_rate: 4.7597e-09
# Epoch 79/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.9779 - loss: 0.1004 - val_accuracy: 0.9413 - val_loss: 0.2272 - learning_rate: 3.1860e-09
# Epoch 80/200
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 46s 688ms/step - accuracy: 0.9817 - loss: 0.0859 - val_accuracy: 0.9413 - val_loss: 0.2279 - learning_rate: 2.1090e-09

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

test_generator.reset()
preds = model.predict(test_generator)
preds = np.argmax(preds, axis=1)
true_labels = test_generator.classes
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 991ms/step - accuracy: 0.9078 - loss: 0.2968
# Test Accuracy: 0.9327
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 486ms/step

# %%
threshold = 0.5 
preds = (model.predict(test_generator)[:, 1] > threshold).astype(int)

test_precision = precision_score(true_labels, preds)
test_recall = recall_score(true_labels, preds)
f1 = f1_score(true_labels, preds)
conf_matrix = confusion_matrix(true_labels, preds)

print(f'F1 Score: {f1:.4f}')
print(f'Test Precision: {test_precision:.4f}')
print(f'Test Recall: {test_recall:.4f}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step
# F1 Score: 0.9471
# Test Precision: 0.9212
# Test Recall: 0.9745
# Confusion Matrix:
# [[230  36]
#  [ 11 421]]

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
